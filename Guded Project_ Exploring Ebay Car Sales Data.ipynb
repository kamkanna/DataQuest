# %% [markdown]
# ## About the project
# The aim of this priject is to clean the data and analyze the included used car listings.
# The used data set from Ebay Kleinzeigen, a classifyied section of German Website. The data set was originally scraped and uploaded to Kaggle.
#
# The data dictionary provided with data is as follows:
#
# * dateCrawled - When this ad was first crawled. All field-values are taken from this date.
# * name - Name of the car.
# * seller - Whether the seller is private or a dealer.
# * offerType - The type of listing
# * price - The price on the ad to sell the car.
# * abtest - Whether the listing is included in an A/B test.
# * vehicleType - The vehicle Type.
# * yearOfRegistration - The year in which year the car was first registered.
# * gearbox - The transmission type.
# * powerPS - The power of the car in PS.
# * model - The car model name.
# * kilometer - How many kilometers the car has driven.
# * monthOfRegistration - The month in which which year the car was first registered.
# * fuelType - What type of fuel the car uses.
# * brand - The brand of the car.
# * notRepairedDamage - If the car has a damage which is not yet repaired.
# * dateCreated - The date on which the eBay listing was created.
# * nrOfPictures - The number of pictures in the ad.
# * postalCode - The postal code for the location of the vehicle.
# * lastSeenOnline - When the crawler saw this ad last online.

# %%
import pandas as pd

# %%
autos = pd.read_csv("autos.csv", encoding="Latin-1")

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# ## Observations:
#     - The data set has 20 columns and mostly are strings.
#     - all columns have null-value
#     - only five colums are int and the reast are objects. e.g. price, odometr, date and last seen are numbers but the type is object.
#     - column names are not of lower register
#     - some columns don't have entries e.g. vehicleType, gearbox, model, fuel type, not repaird damage.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %% [markdown]
# ## The code below converts clumn names to snakecase.
# The column names uses caelcase instead of Python's preferred snakecase.

# %%
cols_edit = ['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
       'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
       'odometer', 'registration_month', 'fuel_type', 'brand',
       'urepaired_damage', 'ad_created', 'nr_of_pictures', 'postal_code',
       'last_seen']
autos.columns = cols_edit
#chek edited columns
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# ## Basic data exploration and cleaning

# %%
autos.describe(include="all")
# Out:
#                date_crawled         name  seller offer_type  price abtest  \
# count                 50000        50000   50000      50000  50000  50000
# unique                48213        38754       2          2   2357      2
# top     2016-03-30 19:48:02  Ford_Fiesta  privat    Angebot     $0   test
# freq                      3           78   49999      49999   1421  25756
# mean                    NaN          NaN     NaN        NaN    NaN    NaN
# std                     NaN          NaN     NaN        NaN    NaN    NaN
# min                     NaN          NaN     NaN        NaN    NaN    NaN
# 25%                     NaN          NaN     NaN        NaN    NaN    NaN
# 50%                     NaN          NaN     NaN        NaN    NaN    NaN
# 75%                     NaN          NaN     NaN        NaN    NaN    NaN
# max                     NaN          NaN     NaN        NaN    NaN    NaN
#
#        vehicle_type  registration_year  gearbox      power_ps  model  \
# ...

# %% [markdown]
# Columns that have mostly one value and candidated to be dropped:
#     - seller, offer type, abtest, gearbox, unrepaired damage, nr_of_pictures
# Columns to investigate more:
#     - data_crawled, ad_created, name
# Numeric columns to be cleaned:
#     - odometr, price,

# %% [markdown]
# ## Columns investigation
# Columns date_crawled, ad_created and last_seen are dates. These columns can be converted to date format

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# date_crawled          50000 non-null object
# name                  50000 non-null object
# seller                50000 non-null object
# offer_type            50000 non-null object
# price                 50000 non-null object
# abtest                50000 non-null object
# vehicle_type          44905 non-null object
# registration_year     50000 non-null int64
# gearbox               47320 non-null object
# power_ps              50000 non-null int64
# model                 47242 non-null object
# odometer              50000 non-null object
# registration_month    50000 non-null int64
# fuel_type             45518 non-null object
# brand                 50000 non-null object
# urepaired_damage      40171 non-null object
# ad_created            50000 non-null object
# nr_of_pictures        50000 non-null int64
# postal_code           50000 non-null int64
# ...

# %%
print(autos["date_crawled"].unique())
print(autos["ad_created"].unique())
# Out:
# ['2016-03-26 17:47:46' '2016-04-04 13:38:56' '2016-03-26 18:57:24' ...
#  '2016-03-28 10:50:25' '2016-03-08 19:25:42' '2016-03-14 00:42:12']
# ['2016-03-26 00:00:00' '2016-04-04 00:00:00' '2016-03-12 00:00:00'
#  '2016-04-01 00:00:00' '2016-03-21 00:00:00' '2016-03-20 00:00:00'
#  '2016-03-16 00:00:00' '2016-03-22 00:00:00' '2016-03-14 00:00:00'
#  '2016-03-31 00:00:00' '2016-03-23 00:00:00' '2016-03-29 00:00:00'
#  '2016-03-17 00:00:00' '2016-03-05 00:00:00' '2016-03-06 00:00:00'
#  '2016-03-28 00:00:00' '2016-03-10 00:00:00' '2016-04-03 00:00:00'
#  '2016-03-27 00:00:00' '2016-03-19 00:00:00' '2016-04-02 00:00:00'
#  '2016-03-15 00:00:00' '2016-04-05 00:00:00' '2016-03-11 00:00:00'
#  '2016-03-07 00:00:00' '2016-03-08 00:00:00' '2016-03-09 00:00:00'
#  '2016-03-25 00:00:00' '2016-03-18 00:00:00' '2016-03-30 00:00:00'
#  '2016-03-24 00:00:00' '2016-03-13 00:00:00' '2016-04-06 00:00:00'
#  '2016-03-04 00:00:00' '2016-04-07 00:00:00' '2016-02-24 00:00:00'
# ...

# %%
autos["name"].unique()
# Out:
# array(['Peugeot_807_160_NAVTECH_ON_BOARD',
#        'BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik',
#        'Volkswagen_Golf_1.6_United', ...,
#        'Audi_Q5_3.0_TDI_qu._S_tr.__Navi__Panorama__Xenon',
#        'Opel_Astra_F_Cabrio_Bertone_Edition___TÜV_neu+Reifen_neu_!!',
#        'Fiat_500_C_1.2_Dualogic_Lounge'], dtype=object)

# %% [markdown]
# Columns date_crawled and ad_created are dates. These columns can be converted to date format

# %% [markdown]
# ## Data claning

# %%
autos["price"].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
autos["price"] = (autos["price"].str.replace("$", "")
                      .str.replace(",", "")
                      .astype(int)
                 )

# %%
autos["odometer"].unique()
# Out:
# array(['150,000km', '70,000km', '50,000km', '80,000km', '10,000km',
#        '30,000km', '125,000km', '90,000km', '20,000km', '60,000km',
#        '5,000km', '100,000km', '40,000km'], dtype=object)

# %%
autos["odometer"] = (autos["odometer"].str.replace("km", "")
                         .str.replace(",", "")
                         .astype(int)
                    )
autos["odometer_km"] = autos["odometer"]

# %% [markdown]
# ## Data analysis (odometer_km, price)

# %% [markdown]
# Odometer_km - Investigation of outliers

# %%
print(autos["odometer_km"].unique())
print(autos["odometer_km"].unique().shape)
print(autos["odometer_km"].value_counts())
autos["odometer_km"].describe()
# Out:
# [150000  70000  50000  80000  10000  30000 125000  90000  20000  60000
#    5000 100000  40000]
# (13,)
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# No outliers have been observed in the column odometer_km. The column has been kept withput any changes. It seems people temd to round the odoemeter values since there are only 13 unique values out of 50K.

# %% [markdown]
# Price - Investigation of outliers.

# %%
print(autos["price"].unique())
print(autos["price"].unique().shape)
print(autos["price"].describe())
autos["price"].value_counts().head(10)
# Out:
# [ 5000  8500  8990 ...   385 22200 16995]
# (2357,)
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64
# 0       1421
# 500      781
# 1500     734
# 2500     643
# 1000     639
# 1200     639
# 600      531
# 800      498
# 3500     498
# 2000     460
# Name: price, dtype: int64

# %% [markdown]
# There are 1421 ads with price 0$. This is 2% of all data. So, these rows can be removed.
#
# The highest price is one hundread million dollars. It seems very high price. Let's look at the highest prices.

# %%
autos["price"].value_counts().sort_index(ascending=False).head(20)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# Name: price, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending=True).head(20)
# Out:
# 0     1421
# 1      156
# 2        3
# 3        1
# 5        2
# 8        1
# 9        1
# 10       7
# 11       2
# 12       3
# 13       2
# 14       1
# 15       2
# 17       3
# 18       1
# 20       4
# 25       5
# 29       1
# 30       7
# 35       1
# Name: price, dtype: int64

# %% [markdown]
# There are 15 listings with a price over \$1M what is less than \0.001% of all listings. And 1500 listings with price lower by \$30 including 1421 listings at price 0$.
#
# Apparently the price of \$1 used to make a bit on eBay. Therefore, considering to keep listing at \$1 and higer and removing listing above $350K.

# %%
autos = autos[autos["price"].between(1,351000)]
autos["price"].describe()
# Out:
# count     48565.000000
# mean       5888.935591
# std        9059.854754
# min           1.000000
# 25%        1200.000000
# 50%        3000.000000
# 75%        7490.000000
# max      350000.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Exploring Data Columns

# %% [markdown]
# There are 5 columns that should represent date values. Some of these columns were created by the crawler, some came from the website itself. We can differentiate by referring to the data dictionary:
# - `date_crawled`: added by the crawler
# - `last_seen`: added by the crawler
# - `ad_created`: from the website
# - `registration_month`: from the website
# - `registration_year`: from the website

# %%
autos[['date_crawled','ad_created','last_seen']][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
(autos['date_crawled']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_index(ascending=True)
    )
# Out:
# 2016-03-05    0.025327
# 2016-03-06    0.014043
# 2016-03-07    0.036014
# 2016-03-08    0.033296
# 2016-03-09    0.033090
# 2016-03-10    0.032184
# 2016-03-11    0.032575
# 2016-03-12    0.036920
# 2016-03-13    0.015670
# 2016-03-14    0.036549
# 2016-03-15    0.034284
# 2016-03-16    0.029610
# 2016-03-17    0.031628
# 2016-03-18    0.012911
# 2016-03-19    0.034778
# 2016-03-20    0.037887
# 2016-03-21    0.037373
# 2016-03-22    0.032987
# 2016-03-23    0.032225
# 2016-03-24    0.029342
# 2016-03-25    0.031607
# 2016-03-26    0.032204
# 2016-03-27    0.031092
# 2016-03-28    0.034860
# 2016-03-29    0.034099
# 2016-03-30    0.033687
# 2016-03-31    0.031834
# 2016-04-01    0.033687
# 2016-04-02    0.035478
# 2016-04-03    0.038608
# 2016-04-04    0.036487
# 2016-04-05    0.013096
# 2016-04-06    0.003171
# 2016-04-07    0.001400
# Name: date_crawled, dtype: float64

# %%
(autos['date_crawled']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_values(ascending=True)
    )
# Out:
# 2016-04-07    0.001400
# 2016-04-06    0.003171
# 2016-03-18    0.012911
# 2016-04-05    0.013096
# 2016-03-06    0.014043
# 2016-03-13    0.015670
# 2016-03-05    0.025327
# 2016-03-24    0.029342
# 2016-03-16    0.029610
# 2016-03-27    0.031092
# 2016-03-25    0.031607
# 2016-03-17    0.031628
# 2016-03-31    0.031834
# 2016-03-10    0.032184
# 2016-03-26    0.032204
# 2016-03-23    0.032225
# 2016-03-11    0.032575
# 2016-03-22    0.032987
# 2016-03-09    0.033090
# 2016-03-08    0.033296
# 2016-03-30    0.033687
# 2016-04-01    0.033687
# 2016-03-29    0.034099
# 2016-03-15    0.034284
# 2016-03-19    0.034778
# 2016-03-28    0.034860
# 2016-04-02    0.035478
# 2016-03-07    0.036014
# 2016-04-04    0.036487
# 2016-03-14    0.036549
# 2016-03-12    0.036920
# 2016-03-21    0.037373
# 2016-03-20    0.037887
# 2016-04-03    0.038608
# Name: date_crawled, dtype: float64

# %% [markdown]
# It looks like the sate was crawled every day over a month in the period March-April 2016. The listing  distribution looks roughly uniform.

# %%
(autos['ad_created']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_index(ascending=True)
    )
# Out:
# 2015-06-11    0.000021
# 2015-08-10    0.000021
# 2015-09-09    0.000021
# 2015-11-10    0.000021
# 2015-12-05    0.000021
# 2015-12-30    0.000021
# 2016-01-03    0.000021
# 2016-01-07    0.000021
# 2016-01-10    0.000041
# 2016-01-13    0.000021
# 2016-01-14    0.000021
# 2016-01-16    0.000021
# 2016-01-22    0.000021
# 2016-01-27    0.000062
# 2016-01-29    0.000021
# 2016-02-01    0.000021
# 2016-02-02    0.000041
# 2016-02-05    0.000041
# 2016-02-07    0.000021
# 2016-02-08    0.000021
# 2016-02-09    0.000021
# 2016-02-11    0.000021
# 2016-02-12    0.000041
# 2016-02-14    0.000041
# 2016-02-16    0.000021
# 2016-02-17    0.000021
# 2016-02-18    0.000041
# 2016-02-19    0.000062
# 2016-02-20    0.000041
# 2016-02-21    0.000062
#                 ...
# 2016-03-09    0.033151
# 2016-03-10    0.031895
# 2016-03-11    0.032904
# 2016-03-12    0.036755
# 2016-03-13    0.017008
# 2016-03-14    0.035190
# 2016-03-15    0.034016
# 2016-03-16    0.030125
# 2016-03-17    0.031278
# ...

# %%
(autos['ad_created']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_values(ascending=True)
    )
# Out:
# 2016-01-16    0.000021
# 2015-12-30    0.000021
# 2016-02-01    0.000021
# 2016-01-29    0.000021
# 2016-02-09    0.000021
# 2016-02-07    0.000021
# 2015-08-10    0.000021
# 2016-02-08    0.000021
# 2016-02-16    0.000021
# 2016-01-03    0.000021
# 2015-12-05    0.000021
# 2016-02-22    0.000021
# 2016-01-14    0.000021
# 2016-02-17    0.000021
# 2015-06-11    0.000021
# 2016-02-11    0.000021
# 2016-01-22    0.000021
# 2016-01-13    0.000021
# 2015-09-09    0.000021
# 2016-01-07    0.000021
# 2015-11-10    0.000021
# 2016-02-05    0.000041
# 2016-02-14    0.000041
# 2016-02-02    0.000041
# 2016-02-26    0.000041
# 2016-02-18    0.000041
# 2016-02-20    0.000041
# 2016-02-12    0.000041
# 2016-02-24    0.000041
# 2016-01-10    0.000041
#                 ...
# 2016-03-06    0.015320
# 2016-03-13    0.017008
# 2016-03-05    0.022897
# 2016-03-24    0.029280
# 2016-03-16    0.030125
# 2016-03-27    0.030989
# 2016-03-17    0.031278
# 2016-03-25    0.031751
# 2016-03-31    0.031875
# ...

# %% [markdown]
# The more ads were created in March-April 2016. In the period November 2015 - February 2016 the ads activity is quite low. Not many ads were published.

# %%
(autos['last_seen']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_index(ascending=True)
    )
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %%
(autos['last_seen']
     .str[:10]
     .value_counts(normalize=True, dropna=False)
     .sort_values(ascending=True)
    )
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-18    0.007351
# 2016-03-08    0.007413
# 2016-03-13    0.008895
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-14    0.012602
# 2016-03-27    0.015649
# 2016-03-19    0.015834
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-26    0.016802
# 2016-03-23    0.018532
# 2016-03-25    0.019211
# 2016-03-24    0.019767
# 2016-03-21    0.020632
# 2016-03-20    0.020653
# 2016-03-28    0.020859
# 2016-03-22    0.021373
# 2016-03-29    0.022341
# 2016-04-01    0.022794
# 2016-03-12    0.023783
# 2016-03-31    0.023783
# 2016-04-04    0.024483
# 2016-03-30    0.024771
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-03-17    0.028086
# 2016-04-05    0.124761
# 2016-04-07    0.131947
# 2016-04-06    0.221806
# Name: last_seen, dtype: float64

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %% [markdown]
# Min and max are odd values. Min year is far from the your of first invented car in 1895. The max year is from far future.

# %% [markdown]
# ## Investigation of registration year

# %% [markdown]
# The outliers of registration column should be removed. Before it will br done let's seew what's the percentage of the data has odd values.
# The first car was invented in 1895. Therefore, the year range should be 1895 - 2016.

# %%
(~autos["registration_year"].between(1900,2016)).sum() / autos.shape[0]
# Out:
# 0.038793369710697

# %% [markdown]
# There are 4% listings out of the year range. Therefore, these listings will be removed.

# %%
autos = autos[autos["registration_year"].between(1895,2016)]
print(autos["registration_year"].describe())
autos["registration_year"].value_counts(normalize=True)
# Out:
# count    46681.000000
# mean      2002.910756
# std          7.185103
# min       1910.000000
# 25%       1999.000000
# 50%       2003.000000
# 75%       2008.000000
# max       2016.000000
# Name: registration_year, dtype: float64
# 2000    0.067608
# 2005    0.062895
# 1999    0.062060
# 2004    0.057904
# 2003    0.057818
# 2006    0.057197
# 2001    0.056468
# 2002    0.053255
# 1998    0.050620
# 2007    0.048778
# 2008    0.047450
# 2009    0.044665
# 1997    0.041794
# 2011    0.034768
# 2010    0.034040
# 1996    0.029412
# 2012    0.028063
# 1995    0.026285
# 2016    0.026135
# 2013    0.017202
# 2014    0.014203
# 1994    0.013474
# 1993    0.009104
# 2015    0.008397
# 1992    0.007926
# 1990    0.007433
# 1991    0.007262
# 1989    0.003727
# 1988    0.002892
# 1985    0.002035
#           ...
# 1966    0.000471
# 1976    0.000450
# 1969    0.000407
# 1975    0.000386
# 1965    0.000364
# 1964    0.000257
# 1963    0.000171
# 1959    0.000129
# 1961    0.000129
# ...

# %% [markdown]
# The more cars of this distribution have been registered in the period 1994-2016.

# %% [markdown]
# ## Exploring Price by Brand

# %%
print(autos["brand"].unique())
autos["brand"].value_counts(normalize=True)
# Out:
# ['peugeot' 'bmw' 'volkswagen' 'smart' 'ford' 'chrysler' 'seat' 'renault'
#  'mercedes_benz' 'audi' 'sonstige_autos' 'opel' 'mazda' 'porsche' 'mini'
#  'toyota' 'dacia' 'nissan' 'jeep' 'saab' 'volvo' 'mitsubishi' 'jaguar'
#  'fiat' 'skoda' 'subaru' 'kia' 'citroen' 'chevrolet' 'hyundai' 'honda'
#  'daewoo' 'suzuki' 'trabant' 'land_rover' 'alfa_romeo' 'lada' 'rover'
#  'daihatsu' 'lancia']
# volkswagen        0.211264
# bmw               0.110045
# opel              0.107581
# mercedes_benz     0.096463
# audi              0.086566
# ford              0.069900
# renault           0.047150
# peugeot           0.029841
# fiat              0.025642
# seat              0.018273
# skoda             0.016409
# nissan            0.015274
# mazda             0.015188
# smart             0.014160
# citroen           0.014010
# toyota            0.012703
# hyundai           0.010025
# sonstige_autos    0.009811
# volvo             0.009147
# mini              0.008762
# ...

# %% [markdown]
# Despite the fact that half of listings presented by German brends. Let's look at the prices of top-10 brands.
# - volkswagen
# - bmw
# - opel
# - mercedes_benz
# - audi
# - ford
# - renault
# - peugeot
# - fiat
# - seat

# %%
brand = autos["brand"].value_counts().head(10).index
brand_mean_price = {}

for b in brand:
    selected_rows = autos[autos['brand'] == b]
    mean_price = selected_rows['price'].mean()
    brand_mean_price[b] = int(mean_price)
    
brand_mean_price
# Out:
# {'audi': 9336,
#  'bmw': 8332,
#  'fiat': 2813,
#  'ford': 3749,
#  'mercedes_benz': 8628,
#  'opel': 2975,
#  'peugeot': 3094,
#  'renault': 2474,
#  'seat': 4397,
#  'volkswagen': 5402}

# %% [markdown]
# There is a price gap between popular brend:
# - The last top-5 brends, Seat, Feat, Peugeot, Renault, Ford are in price rnge of \$2474 - 4397.
# - The most expensive brands are Audi, BMW, Mercedes-Benz with average price of \$8300-9300.
# - The most popular brens, Volkswagen, has average price of \$5400. That is between the cheap brands and expensive ones. It may be the best option of cheap and expensive worlds.

# %% [markdown]
# ## Exploring Mileage

# %% [markdown]
# For the top 10 brands, let's use aggregation to understand the average mileage for those cars and if there's any visible link with mean price.

# %%
bmp_series = pd.Series(brand_mean_price)
bmp_series
# Out:
# audi             9336
# bmw              8332
# fiat             2813
# ford             3749
# mercedes_benz    8628
# opel             2975
# peugeot          3094
# renault          2474
# seat             4397
# volkswagen       5402
# dtype: int64

# %%
pd.DataFrame(bmp_series, columns=['mean_mileage'])
# Out:
#                mean_mileage
# audi                   9336
# bmw                    8332
# fiat                   2813
# ford                   3749
# mercedes_benz          8628
# opel                   2975
# peugeot                3094
# renault                2474
# seat                   4397
# volkswagen             5402

# %%
brand_mean_mileage = {}

for b in brand:
    selected_rows = autos[autos['brand'] == b]
    mean_mileage = selected_rows['odometer_km'].mean()
    brand_mean_mileage[b] = int(mean_mileage)
    
brand_mean_mileage
# Out:
# {'audi': 129157,
#  'bmw': 132572,
#  'fiat': 117121,
#  'ford': 124266,
#  'mercedes_benz': 130788,
#  'opel': 129310,
#  'peugeot': 127153,
#  'renault': 128071,
#  'seat': 121131,
#  'volkswagen': 128707}

# %%
mean_price = pd.Series(brand_mean_price).sort_values(ascending=False)
mean_mileage = pd.Series(brand_mean_mileage).sort_values(ascending=False)

# %%
brand_mean_price_mileage = pd.DataFrame(mean_mileage, columns=['mean_mileage'])
brand_mean_price_mileage
# Out:
#                mean_mileage
# bmw                  132572
# mercedes_benz        130788
# opel                 129310
# audi                 129157
# volkswagen           128707
# renault              128071
# peugeot              127153
# ford                 124266
# seat                 121131
# fiat                 117121

# %%
brand_mean_price_mileage['mean_price'] = mean_price
brand_mean_price_mileage
# Out:
#                mean_mileage  mean_price
# bmw                  132572        8332
# mercedes_benz        130788        8628
# opel                 129310        2975
# audi                 129157        9336
# volkswagen           128707        5402
# renault              128071        2474
# peugeot              127153        3094
# ford                 124266        3749
# seat                 121131        4397
# fiat                 117121        2813

# %% [markdown]
# There is not a big gap in mileage of the top brands. Theere is a mileage trend. The more expensive car the higher th mileage.
